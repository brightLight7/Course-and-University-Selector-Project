# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set in environment variables.")
    print("If you have already set the key, please check the .env file in the AI directory.")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI
openai = OpenAI()

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

from openai import OpenAI
openai = OpenAI()

import json

with open('../data/jsonFiles/personaTest1.json') as file:
    persona_test1 = json.load(file)

with open('../data/jsonFiles/testUniversitiesTemplate.json') as file:
    test_universities = json.load(file)

with open('../data/jsonFiles/testCoursesTemplate.json') as file:
    test_courses = json.load(file)

# print(persona_test1)

response = openai.chat.completions.create(
    model="gpt-4",
    messages=[
        {
            "role": "system",
            "content": "You are an expert course and university advisor. Based on the user's quiz answers, recommend the top 3 most suitable courses and universities from the provided lists. Justify each recommendation with specific reasons related to the user's preferences and needs."
        },
        {
            "role": "user",
            "content": f"Quiz Answers: {json.dumps(persona_test1)}\n\nAvailable Universities: {json.dumps(test_universities)}\n\nAvailable Courses: {json.dumps(test_courses)}\n\nPlease provide your recommendations."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Based on the quiz answers provided, considering factors including career outcomes, broad courses, problem-solving skills, medium confidence of meeting entry requirements, a learning style that includes lectures and projects, and selected priorities including course content, employability, and university rankings, here are my top three recommendations:
#
# 1. Course: "Computer Science BSc" at the University of Oxford
# Both the course discipline, computing, and the university have a very strong reputation, which aligns with your concern about university rankings and employability. The course offers a broad overview of the field, which matches your preference for a broad course, and also emphasizes problem-solving, an area you feel strong in. The entry requirements are high, but it's worth considering given your medium confidence in meeting entry requirements.
#
# 2. Course: "Business Management BSc" at University of Warwick
# This course is broad and likely touches on a variety of problems and strategic planning, capitalizing on your problem-solving skills. The university is well-regarded, and the business field generally has good career outcomes. Your preference for project-based assessments is aligned with opportunities for practical assessments in this course.
#
# 3. Course: "Civil Engineering BEng" at University of Leeds
# Engineering is a broad field with a focus on problem-solving, which suits your preferences and strengths. The University of Leeds has strong industry links and great employability outcomes, and while the entry requirements are reasonable, it's noteworthy that projects form an important part of the course’s assessments, which you indicated as your preferred type.
#
# Make sure to double-check with the universities to get up-to-date information on tuition costs, given that you indicated this is an important factor to you. Also, ensure you research the course content more deeply to validate it aligns with your career aspirations.
